# %% [markdown]
# # FTP - % of Bachelor's degree conferred to women (1970 - 2011) in the US

# %% [markdown]
# **Summary:**
# * Women dominated majors (above 50%):
#     * Health Professions, Public Administration, Education, Foreign Languages and English - best from 1970 to today
#     * Psycology and Art and Performance - between 40% and 60% by 1970 and above 60% today
#     * Communications and Journalism and Biology - slightly above 20% in 1970, above 50% today

# %%
import pandas as pd
import os
import glob

cwd = os.getcwd()
path = "../data/"

# %matplotlib inline

# %%
women_majors = pd.read_csv(path + 'percent-bachelors-degrees-women-usa.csv')

# %% [markdown]
# # Check the data

# %%
women_majors.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 18 columns):
# Year                             42 non-null int64
# Agriculture                      42 non-null float64
# Architecture                     42 non-null float64
# Art and Performance              42 non-null float64
# Biology                          42 non-null float64
# Business                         42 non-null float64
# Communications and Journalism    42 non-null float64
# Computer Science                 42 non-null float64
# Education                        42 non-null float64
# Engineering                      42 non-null float64
# English                          42 non-null float64
# Foreign Languages                42 non-null float64
# Health Professions               42 non-null float64
# Math and Statistics              42 non-null float64
# Physical Sciences                42 non-null float64
# Psychology                       42 non-null float64
# ...

# %%
# 42 entries, 18 columns

# %%
women_majors.head()
# Out:
#    Year  Agriculture  Architecture  Art and Performance    Biology   Business  \
# 0  1970     4.229798     11.921005                 59.7  29.088363   9.064439
# 1  1971     5.452797     12.003106                 59.9  29.394403   9.503187
# 2  1972     7.420710     13.214594                 60.4  29.810221  10.558962
# 3  1973     9.653602     14.791613                 60.2  31.147915  12.804602
# 4  1974    14.074623     17.444688                 61.9  32.996183  16.204850
#
#    Communications and Journalism  Computer Science  Education  Engineering  \
# 0                           35.3              13.6  74.535328          0.8
# 1                           35.5              13.6  74.149204          1.0
# 2                           36.6              14.9  73.554520          1.2
# 3                           38.4              16.4  73.501814          1.6
# 4                           40.5              18.9  73.336811          2.2
#
# ...

# %%
# 42 non-null for each 18 data columns

# %% [markdown]
# # Visualization

# %% [markdown]
# ### 1) Evolution of Bachelor degree where percentage of women graduates was less than 20% in 1970

# %%
# I will select the first row, which corresponds to 1970
# I will select the columns (fields) in which the values are less than 20 (%)

# %%
under_20 = women_majors.loc[0, women_majors.loc[0]<20]

# %%
under_20
# Out:
# Agriculture           4.229798
# Architecture         11.921005
# Business              9.064439
# Computer Science     13.600000
# Engineering           0.800000
# Physical Sciences    13.800000
# Name: 0, dtype: float64

# %%
under_20_graph = women_majors.plot(x = 'Year', y = under_20.index, figsize = (12,8))

# %%
# The above uses matplotlib's default style
# To view a list of all the available in-built styles:

# %%
import matplotlib.style as style
style.available
# Out:
# [u'seaborn-darkgrid',
#  u'seaborn-notebook',
#  u'classic',
#  u'seaborn-ticks',
#  u'grayscale',
#  u'bmh',
#  u'seaborn-talk',
#  u'dark_background',
#  u'ggplot',
#  u'fivethirtyeight',
#  u'seaborn-colorblind',
#  u'seaborn-deep',
#  u'seaborn-whitegrid',
#  u'seaborn-bright',
#  u'seaborn-poster',
#  u'seaborn-muted',
#  u'seaborn-paper',
#  u'seaborn-white',
#  u'seaborn-pastel',
#  u'seaborn-dark',
#  u'seaborn',
#  u'seaborn-dark-palette']

# %%
style.use('fivethirtyeight')
# If I'd like to return to default style:
# style.use('default')

# %%
women_majors.plot(x = 'Year', y = under_20.index, figsize = (12,8))

# %%
## It still needs some work:

# remove legend and add lables near plot line. Replace the default colours with colourblind-friendly colours

# replace the default colours with colourblind-friendly colours

# font size of tick labels needs to be increased. It will be achieved by using tick_params() method

# '%' will be added to the highest y-axis tick label 

# whitespace will be added to align the characters to the '50%'

# bold horizontal line where y = 0. It will be achieved by using axhline() method 

# add vertical line. I will need to increase the range of the x-axis

# remove x-axis label

# add signature bar using the text() method:
# x and y parameters specify the x and y coordinates of the text
# s = text

# add title nd subtitle

# %%
# Colorblind-friendly colors
colours = [(0.0,0.0,0.0), (230.0/255,159.0/255,0.0), (86.0/255,180.0/255.0,233.0/255), (0.0,158.0/255,115.0/255), 
          (213.0/255,94.0/255,0.0), (0.0,114.0/255,178.0/255), (204.0/255, 121.0/255, 167.0/255)]

# %%
fte_20 = women_majors.plot(x = 'Year', y = under_20.index, figsize = (12,8), color = colours, legend = False)
fte_20.tick_params(axis = 'both', which = 'major', labelsize = 18)

# Customizing y-tick
fte_20.set_yticklabels(labels = [-10, '0    ', '10   ', '20   ', '30   ', '40   ', '50%'])

# Bolded horizontal line
fte_20.axhline(y = 0, color = 'black', linewidth = 1.3, alpha = 0.7)

# Add extra vertical line
fte_20.set_xlim(left = 1969, right = 2011)

# Remove x-axis label
fte_20.xaxis.label.set_visible(False)

# Signature bar
fte_20.text(x = 1965.8, y = -7, 
            s = '    pukkapad / Mariana                                                                        Source: National Center for Education Statistics  '   ,
           fontsize = 14, color = '#f0f0f0',  backgroundcolor = 'grey')

# Title and subtile
fte_20.text(x = 1966.65, y = 62.7,
           s = "Gender gap evolution for extreme cases",
           fontsize = 26, weight = 'bold', alpha = 0.75)

fte_20.text(x = 1966.65, y = 57,
           s = "Percentage of Bachelors conferred to women from 1970 to 2011 in the US for\nextreme cases where the percentage was less than 20% in 1970", 
            fontsize = 19, weight = 'bold', alpha = 0.75)


# Add labels
fte_20.text(x = 1994, y = 44, s = 'Agriculture', color = colours[0], weight = 'bold', rotation = 33,
             backgroundcolor = '#f0f0f0')
fte_20.text(x = 1985, y = 42.2, s = 'Architecture', color = colours[1], weight = 'bold', rotation = 18,
              backgroundcolor = '#f0f0f0')
fte_20.text(x = 2004, y = 51, s = 'Business', color = colours[2], weight = 'bold', rotation = -5, 
               backgroundcolor = '#f0f0f0')
fte_20.text(x = 2001, y = 30, s = 'Computer Science', color = colours[3], weight = 'bold', rotation = -42.5,
              backgroundcolor = '#f0f0f0')
fte_20.text(x = 1987, y = 11.5, s = 'Engineering', color = colours[4], weight = 'bold',
              backgroundcolor = '#f0f0f0')
fte_20.text(x = 1976, y = 25, s = 'Physical Sciences', color = colours[5], weight = 'bold', rotation = 27,
              backgroundcolor = '#f0f0f0')

# %%
# Same thing, different signature bar:

# %%
fte_20 = women_majors.plot(x = 'Year', y = under_20.index, figsize = (12,8), color = colours, legend = False)
fte_20.tick_params(axis = 'both', which = 'major', labelsize = 18)

fte_20.set_yticklabels(labels = [-10, '0    ', '10   ', '20   ', '30   ', '40   ', '50%'])

fte_20.axhline(y = 0, color = 'black', linewidth = 1.3, alpha = 0.7)

fte_20.set_xlim(left = 1969, right = 2011)

fte_20.xaxis.label.set_visible(False)

# Signature bar
fte_20.text(x = 1967.1, y = -6.5,
    s = '________________________________________________________________________________________________________________',
    color = 'grey', alpha = .7)

fte_20.text(x = 1966.1, y = -9, 
            s = '    pukkapad / Mariana                                                                    Source: National Center for Education Statistics  '   ,
           fontsize = 14, color = 'grey', alpha = 0.7)

fte_20.text(x = 1966.65, y = 62.7,
           s = "Gender gap evolution for extreme cases",
           fontsize = 26, weight = 'bold', alpha = 0.75)

fte_20.text(x = 1966.65, y = 57,
           s = "Percentage of Bachelors conferred to women from 1970 to 2011 in the US for\nextreme cases where the percentage was less than 20% in 1970", 
            fontsize = 19, weight = 'bold', alpha = 0.75)

fte_20.text(x = 1994, y = 44, s = 'Agriculture', color = colours[0], weight = 'bold', rotation = 33,
             backgroundcolor = '#f0f0f0')
fte_20.text(x = 1985, y = 42.2, s = 'Architecture', color = colours[1], weight = 'bold', rotation = 18,
              backgroundcolor = '#f0f0f0')
fte_20.text(x = 2004, y = 51, s = 'Business', color = colours[2], weight = 'bold', rotation = -5, 
               backgroundcolor = '#f0f0f0')
fte_20.text(x = 2001, y = 30, s = 'Computer Science', color = colours[3], weight = 'bold', rotation = -42.5,
              backgroundcolor = '#f0f0f0')
fte_20.text(x = 1987, y = 11.5, s = 'Engineering', color = colours[4], weight = 'bold',
              backgroundcolor = '#f0f0f0')
fte_20.text(x = 1976, y = 25, s = 'Physical Sciences', color = colours[5], weight = 'bold', rotation = 27,
              backgroundcolor = '#f0f0f0')

# %% [markdown]
# ### 2) Evolution of Bachelor degree where percentage of women graduates was above 40% in 1970

# %%
above_20 = women_majors.loc[0, (women_majors.loc[0]>40) & (women_majors.loc[0]< 1970)]
fte_above_20 = women_majors.plot(x = 'Year', y = above_20.index, figsize = (12,8), color = colours, legend = False)

fte_above_20.tick_params(axis = 'both', which = 'major', labelsize = 18)

fte_above_20.set_yticklabels(labels = [-10, '40  ', '50   ', '60   ', '70   ', '80%'])

fte_above_20.axhline(y = 40, color = 'black', linewidth = 1.3, alpha = 0.7)

fte_above_20.set_xlim(left = 1969, right = 2011)

fte_above_20.xaxis.label.set_visible(False)

fte_above_20.text(x = 1965.8, y = 31, 
          s = '    pukkapad / Mariana                                                                        Source: National Center for Education Statistics  '   ,
          fontsize = 14, color = '#f0f0f0',  backgroundcolor = 'grey')

fte_above_20.text(x = 1966.65, y = 100,
           s = "Gender gap evolution for best cases",
           fontsize = 26, weight = 'bold', alpha = 0.75)

fte_above_20.text(x = 1966.65, y = 93,
           s = "Percentage of Bachelors conferred to women from 1970 to 2011 in the US for\ncases where the percentage was above than 40% in 1970", 
            fontsize = 19, weight = 'bold', alpha = 0.75)


# Add labels
fte_above_20.text(x = 1981, y = 59, s = 'Art and Performance', color = colours[0], weight = 'bold', rotation = 0,
             backgroundcolor = '#f0f0f0')
fte_above_20.text(x = 1985, y = 80, s = 'Education', color = colours[1], weight = 'bold', rotation = 18,
              backgroundcolor = '#f0f0f0')
fte_above_20.text(x = 1996, y = 65, s = 'English', color = colours[2], weight = 'bold', rotation = 10, 
               backgroundcolor = '#f0f0f0')
fte_above_20.text(x = 2001, y = 72.5, s = 'Foreign Languages', color = colours[3], weight = 'bold', rotation = 0,
              backgroundcolor = '#f0f0f0')
fte_above_20.text(x = 1974, y = 86.5, s = 'Health Professions', color = colours[4], weight = 'bold', rotation = 22,
              backgroundcolor = '#f0f0f0')
fte_above_20.text(x = 1971, y = 57, s = 'Psychology', color = colours[5], weight = 'bold', rotation = 50,
              backgroundcolor = '#f0f0f0')
fte_above_20.text(x = 2001.5, y = 83, s = 'Public Administration', color = colours[6], weight = 'bold', rotation = 0,
              backgroundcolor = '#f0f0f0')

# %% [markdown]
# ### 3) Evolution of Bachelor degree where percentage of women graduates was above 20% and below 40% in 1970

# %%
between_20_40 = women_majors.loc[0, (women_majors.loc[0]>= 20) & (women_majors.loc[0]< 40)]
fte_between_20_40 = women_majors.plot(x = 'Year', y = between_20_40.index, figsize = (12,8), color = colours, legend = False)

fte_between_20_40.tick_params(axis = 'both', which = 'major', labelsize = 18)

fte_between_20_40.set_yticklabels(labels = [-10, '30  ', '35  ', '40  ','45  ',  '50   ','55  ' ,'60   ','65%'])

fte_between_20_40.axhline(y = 30, color = 'black', linewidth = 1.3, alpha = 0.7)

fte_between_20_40.set_xlim(left = 1969, right = 2011)

fte_between_20_40.xaxis.label.set_visible(False)

fte_between_20_40.text(x = 1965.8, y = 23, 
          s = '    pukkapad / Mariana                                                                        Source: National Center for Education Statistics  '   ,
          fontsize = 14, color = '#f0f0f0',  backgroundcolor = 'grey')

fte_between_20_40.text(x = 1966.65, y = 75,
           s = "Gender gap evolution for intermediary cases",
           fontsize = 26, weight = 'bold', alpha = 0.75)

fte_between_20_40.text(x = 1966.65, y = 70,
           s = "Percentage of Bachelors conferred to women from 1970 to 2011 in the US for\ncases where the percentage was above 20% and below 40% in 1970", 
            fontsize = 19, weight = 'bold', alpha = 0.75)

# Add labels
fte_between_20_40.text(x = 1988, y = 53, s = 'Biology', color = colours[0], weight = 'bold', rotation = 17,
             backgroundcolor = '#f0f0f0')
fte_between_20_40.text(x = 1973, y = 60, s = 'Communications and Journalism', color = colours[1], weight = 'bold', rotation = 57,
              backgroundcolor = '#f0f0f0')
fte_between_20_40.text(x = 2001, y = 48, s = 'Math and Statistics', color = colours[2], weight = 'bold', rotation = -17, 
               backgroundcolor = '#f0f0f0')
fte_between_20_40.text(x = 2001, y = 53, s = 'Social Sciences \nand History', color = colours[3], weight = 'bold', rotation = -14,
              backgroundcolor = '#f0f0f0')

# %% [markdown]
# # To do

# %% [markdown]
# ### 1) Automatically add labels to lines

# %%
fte_20 = women_majors.plot(x = 'Year', y = under_20.index, figsize = (12,8), color = colours, legend = False)
fte_20.tick_params(axis = 'both', which = 'major', labelsize = 18)

fte_20.set_yticklabels(labels = [-10, '0    ', '10   ', '20   ', '30   ', '40   ', '50%'])

fte_20.axhline(y = 0, color = 'black', linewidth = 1.3, alpha = 0.7)

fte_20.set_xlim(left = 1969, right = 2011)

fte_20.xaxis.label.set_visible(False)

fte_20.text(x = 1965.8, y = -7, 
            s = '    pukkapad / Mariana                                                                        Source: National Center for Education Statistics  '   ,
           fontsize = 14, color = '#f0f0f0',  backgroundcolor = 'grey')

fte_20.text(x = 1966.65, y = 62.7,
           s = "Gender gap evolution for extreme cases",
           fontsize = 26, weight = 'bold', alpha = 0.75)

fte_20.text(x = 1966.65, y = 57,
           s = "Percentage of Bachelors conferred to women from 1970 to 2011 in the US for\nextreme cases where the percentage was less than 20% in 1970", 
            fontsize = 19, weight = 'bold', alpha = 0.75)

from IPython import display    
for i in range(len(under_20)-1):
    fte_20.text(x = 1994.75 + i, y =  10 * i+2, s = under_20.index[i], color = colours[i], weight = 'bold',
              backgroundcolor = '#f0f0f0')
    display.display(fte_20)

# %%
fte_20 = women_majors.plot(x = 'Year', y = under_20.index, figsize = (12,8), color = colours, legend = False)
fte_20.tick_params(axis = 'both', which = 'major', labelsize = 18)

fte_20.set_yticklabels(labels = [-10, '0    ', '10   ', '20   ', '30   ', '40   ', '50%'])

fte_20.axhline(y = 0, color = 'black', linewidth = 1.3, alpha = 0.7)

fte_20.set_xlim(left = 1969, right = 2011)

fte_20.xaxis.label.set_visible(False)

fte_20.text(x = 1965.8, y = -7, 
            s = '    pukkapad / Mariana                                                                        Source: National Center for Education Statistics  '   ,
           fontsize = 14, color = '#f0f0f0',  backgroundcolor = 'grey')

fte_20.text(x = 1966.65, y = 62.7,
           s = "Gender gap evolution for extreme cases",
           fontsize = 26, weight = 'bold', alpha = 0.75)

fte_20.text(x = 1966.65, y = 57,
           s = "Percentage of Bachelors conferred to women from 1970 to 2011 in the US for\nextreme cases where the percentage was less than 20% in 1970", 
            fontsize = 19, weight = 'bold', alpha = 0.75)

from IPython import display    
for i in range(len(under_20)-1):
    fte_20.text(x = 1994.75 + i, y =  10 * i+2, s = under_20.index[i], color = colours[i], weight = 'bold',
              backgroundcolor = '#f0f0f0')
    display.display(fte_20)
